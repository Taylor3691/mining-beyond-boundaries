# %% [markdown]
# # IMAGE - Chuyển đổi không gian màu và so sánh, luận không gian màu nào bảo toàn thông tin tốt nhất cho bài toán phân loại ảnh.

# %% [markdown]
# # Mục lục
#
# * [1. Lý thuyết không gian màu](#sec-1)
#     * [1.1 Không gian màu là gì ?](#sec-1-1)
#     * [1.2. Các không gian màu phổ biến](#sec-1-2)
#     * [1.3. Ứng dụng của các không gian màu](#sec-1-3)
# * [2. Chuyển đổi qua các không gian màu](#sec-2)
#     * [2.1. Không gian RGB sang không gian Grayscale](#sec-2-1)
#     * [2.2. Không gian RGB sang không gian HSV](#sec-2-2)
#     * [2.3. Không gian RGB sang không gian LAB](#sec-2-3)
#     * [2.4. Tổng kết quá trình tính toán](#sec-2-4)
# * [3. Không gian màu trong bài toán Classification và phương sai giải thích ](#sec-3)
# * [4. Tổng kết thực nghiệm: Phân tích và đánh giá tiền xử lý không gian màu](#sec-5)
#     * [4. 1. Đánh giá dựa trên Phương sai giải thích (Khả năng giữ thông tin)](#sec-5-1)
#     * [4.2. Số lượng màu biểu diễn có quyết định khả năng giữ thông tin?](#sec-5-2)
#     * [4.3. Phân tích Độ đo Chính xác (F1-Score) cho bài toán Phân loại Động vật](#sec-5-3)
#     * [4.4. Bàn luận: Sự đánh đổi giữa Độ phức tạp và Khả năng giữ thông tin](#sec-5-4)

# %% [markdown]
# <a id="sec-1"></a>
#
# # 1. Lý thuyết không gian màu
# [1] Gonzalez, R.C., Woods, R.E., Digital Image Processing, 4th Edition, Pearson, 2018
#
# [2] **ITU-R Recommendation BT.601** – Standard for encoding color images.
#
# [3] Color Science: Concepts and Methods – Günther Wyszecki & W. S. Stiles
#
# <a id="sec-1-1"></a>
#
# ## 1.1 Không gian màu là gì ?
# - Không gian màu (color space hoặc color system) theo định nghĩa trong sách Gonzalet là một không gian hay một mô hình giúp máy tính hoặc con người xác định được giá trị màu thông qua các phương pháp hoặc công thức cụ thể. Bình thường hiện nay thì không gian màu thường được biểu diễn qua hệ thống tọa độ và mỗi màu được biểu diễn là một điểm trong không gian đó.
#
# <figure style="text-align: center;">
#   <img src="./assets/color_space.png" alt="RGB image">
#   <figcaption>https://en.wikipedia.org/wiki/HSL_and_HSV</figcaption>
# </figure>
#
# <a id="sec-1-2"></a>
#
# ## 1.2. Các không gian màu phổ biến
# - **Không gian màu Grayscale**: Mỗi một pixel được biểu diễn bởi một giá trị mức xám trong khoảng [0, 255]
#
# <table style="margin: auto;">
#   <tr>
#     <td align="center">
#       <img src="./assets/grayscale_pallet.png" width="350"><br>
#       Không gian màu xám
#     </td>
#     <td align="center">
#       <img src="./assets/grayscale_flower.png" width="350"><br>
#       Ảnh xám
#     </td>
#   </tr>
# </table>
#
# - **Không gian màu RGB**: Biểu diễn thông qua ba kênh màu cơ bản gồm đỏ (Red), xanh lá (Green) và xanh dương (Blue). Giá trị của các kênh màu trải dài từ [0, 255]
#
# <table style="margin: auto;">
#   <tr>
#     <td align="center">
#       <img src="./assets/RGB_space.png" width="350"><br>
#       Không gian màu RGB
#     </td>
#     <td align="center">
#       <img src="./assets/RGB_bird.png" width="350"><br>
#       Ảnh RGB
#     </td>
#   </tr>
# </table>
#
# - **Không gian màu HSV**: Biểu diễn các màu thông qua phối hợp các thông tin về
#   - Màu sắc (Hue): Biểu diễn giá trị màu sắc trong vòng quang phổ với đơn vị góc có giá trị [0, 179]
#   - Độ bão hòa màu (Saturation): Biểu diễn mức độ bão hòa với mức độ thuộc khoảng [0, 255]
#   - Ánh sáng (Value hoặc Bright): Biểu diễn độ sáng của màu thuộc khoảng [0, 255]
#
# <table style="margin: auto;">
#   <tr>
#     <td align="center">
#       <img src="./assets/HSV_space.png" width="350"><br>
#       Không gian màu HSV
#     </td>
#     <td align="center">
#       <img src="./assets/HSV_detect_shirt.png" width="350"><br>
#       Bài toán tìm áo bằng cách đưa về không gian màu HSV
#     </td>
#   </tr>
# </table>
#
# - **Không gian màu CMY/CMYK**: Trong lĩnh vực in ấn, do mực có khả năng hấp thụ ánh sáng từ ánh sáng trắng và phản xạ các màu còn lại. Vì vậy, người ta đã xây dựng không gian màu riêng xác định màu dựa trên mức độ hấp thụ ánh sáng. Không gian màu được biểu diễn bởi ba giá trị
#   - Cyan (C): Lượng ánh sáng màu đỏ bị hấp thụ, tính bằng công thức C = 1 - R
#   - Magenta (M): Lượng ánh sáng màu xanh lá bị hấp thụ, tính bằng công thức M = 1 - G
#   - Yellow (Y): Lượng ánh sáng màu xanh dương bị hấp thụ, tính bằng công thức Y = 1 - B
#   - Black (K): Đại lượng biểu thị màu đen do C-M-Y không thể hiện được màu đen thuần.
#
# <table style="margin: auto;">
#   <tr>
#     <td align="center">
#       <img src="./assets/CMY_space.png" width="350"><br>
#       Không gian màu CMY
#     </td>
#     <td align="center">
#       <img src="./assets/CMY_led.png" width="350"><br>
#       Các đèn sân khấu chiếu sáng phù hợp với màu sân khấu
#     </td>
#   </tr>
# </table>
#
#
#
# - **Không gian màu LAB**: Hệ màu được xây dựng trên thị giác của người. Các giá trị mà LAB mô tả tất cả các giá trị mà mắt người có thể nhìn thấy được và độc lập với thiết bị, tức là không phụ thuộc thuộc loại thiết bị, tuổi thọ thiết bị,... mà giới hạn khả năng biểu diễn. Trong không gian có các đại lượng
#   - $\Delta L$: Giá trị lớn thì nghiêng về màu trắng và ngược lại nghiêng về màu đen
#   - $\Delta a$: Giá trị lớn thì nghiêng về màu đỏ và ngược lại nghiêng về màu xanh lá
#   - $\Delta b$: Giá trị lớn thì nghiêng về màu vàng và ngược lại nghiêng về màu xanh dương
#
# <table style="margin: auto;">
#   <tr>
#     <td align="center">
#       <img src="./assets/LAB_space.png" width="350"><br>
#       Không gian màu LAB
#     </td>
#     <td align="center">
#       <img src="./assets/LAB_flower.png" width="350"><br>
#       Ảnh tạo ra bởi không gian màu LAB
#     </td>
#   </tr>
# </table>
#
# <a id="sec-1-3"></a>
#
# ## 1.3. Ứng dụng của các không gian màu
# Hiện nay, các không gian màu khác nhau được sử dụng với đa dạng mục đích và tác vụ khác nhau, nhưng nhìn chung đây là một số ứng dụng chính trong việc nghiên cứu và phân tích không gian màu.
#
# - **Grayscale**: Dùng nhiều trong nhận dạng kí tự, camera an ninh do sự đơn giản tính toán, chạy nhanh hơn và tiết kiệm tài nguyên hơn.
# - **RGB**: Được sử dụng rộng rãi trong các màn hình điện thoại, TV có độ phân giải cao, đồ họa máy tính, thiết kế Web do khả năng biểu diễn được không gian màu rộng lớn.
# - **HSV**: Được sử dụng nhiều trong photoshop, tạo bộ chọn màu,... do không gian màu vừa đủ và gần với mắt người nhận diện, dễ thao tác hơn RGB
# - **LAB**: Được sử dụng trong cách phần mềm chỉnh ảnh chuyên nghiệp như ADOBE, đo độ khác biệt màu do tính nhất quán của không gian, không phụ thuộc vào thiết bị và thống nhất trên nhiều hệ thống.
# - **CMY/CMYK**: Được sử dụng rộng rãi trong in ấn, thiết kế màu poster, xuất file in ấn do mục đích kiểm soát màu của tài liệu khi bị hấp thụ bởi ánh sáng. Đặc biệt, CMY còn được ứng dụng trong việc tạo màu cho các đèn sân khấu hiện đại, sử dụng rộng rãi trong các sự kiện, hội nghị và biểu diễn nghệ thuật do các ưu điểm như độ chính xác màu cao, chuyển màu mượt mà, tiết kiệm năng lượng và phù hợp với các buổi diễn nghệ thuật đòi hỏi đèn phù hợp với sân khấu

# %% [markdown]
# <a id="sec-2"></a>
#
# # 2. Chuyển đổi qua các không gian màu
# Một trong những nhiệm vụ tiền xử lý quan trọng trong các hệ thống xử lý ảnh chính là đưa về không gian màu tiện cho việc xử lý. Ở đây để cho thuận tiện, ta sẽ viết công thức chuyển đổi từ không gian RGB sang các không gian khác. Trong xử lý ảnh thông thường, một bức ảnh RGB được biểu diễn như sau:
#
# <figure style="text-align: center;">
#   <img src="./assets/RGB_image_visualize.png" alt="RGB image">
#   <figcaption>Mỗi pixel được biểu diễn bởi giá trị của ba kênh màu R-G-B</figcaption>
# </figure>
#
# <a id="sec-2-1"></a>
#
# ## 2.1. Không gian RGB sang không gian Grayscale
# Ảnh RGB (3 kênh) khi chuyển sang ảnh xám (1 kênh) thì có công thức tổng hợp trọng số Luminance [1] như sau
# $$
# G(x,y) = 0.299 \cdot R(x,y) + 0.587 \cdot G(x,y) + 0.114 \cdot B(x,y)
# $$
#
# Nhưng từ ảnh Grayscale thì không thể chuyển thành ảnh RGB
# ### Không gian RGB sang không gian CMY/CMYK
# - Để chuyển ảnh RGB sang CMY thì ta có công thức sau (mặc định đã chuẩn hóa ảnh RGB trong đoạn [0,1])
# $$
# \begin{bmatrix}
# C \\
# M \\
# Y
# \end{bmatrix}
# =
# \begin{bmatrix}
# 1 \\
# 1 \\
# 1
# \end{bmatrix}
# -
# \begin{bmatrix}
# R \\
# G \\
# B
# \end{bmatrix}
# $$
# Hiểu đơn giản là CMY chính là phần bị ánh sáng hấp thụ, phần còn lại phản xạ lại vào mắt, ta có thể viết lại công thức cho hình dung dễ hơn
#
# $$
# \begin{bmatrix}
# R \\
# G \\
# B
# \end{bmatrix}
# =
# \begin{bmatrix}
# 1 \\
# 1 \\
# 1
# \end{bmatrix}
# -
# \begin{bmatrix}
# C \\
# M \\
# Y
# \end{bmatrix}
# $$
#
# Ví dụ nói về khả năng hấp thụ ánh sáng đỏ của giá trị Cyan (C), tương tự như M và Y
# |Giá trị C| Kết quả|
# |---|---|
# | C = 0|Màu đỏ không bị hấp thụ, phản xạ lại hết, người có thể nhìn rõ màu đỏ|
# | 0 < C < 1| Màu đỏ bị hấp thụ một phần và phản xạ một phần, người thấy màu đỏ mờ mờ|
# | C = 1| Màu đỏ bị hấp thụ hoàn toàn, mắt người không thể nhìn màu đỏ|
#
# Từ công thức trên, hai không gian màu RGB và CMY chuyển qua lại khá đơn giản bằng một phép tính, sau này khi người ta mong muốn tài liêu, poster, quảng cáo phản xạ màu mong muốn thì người ta sẽ chỉnh C,M,Y để hấp thụ các ánh sáng không cần thiết và tạo màu đẹp hơn.
# - Chuyển từ không gian CMY sang CMYK thì chỉ cần chọn thêm K = min(C,M,Y)
#
# <a id="sec-2-2"></a>
#
# ## 2.2. Không gian RGB sang không gian HSV
# Không gian màu RGB có khoảng ~16,8 triệu màu rất tốn tài nguyên để biểu diễn hết, trong khi HSV có thể biểu diễn lại chỉ cần một không gian nhỏ hơn tầm 300 ngàn màu. Đây là lí do người ta thường hay xử lý trong không gian HSV, dưới đây công thức chuyển đổi
#
# Đại lượng H được tính bởi biểu thức sau
# $$
# H =
# \begin{cases}
# \theta & \text{if } B \leq G \\
# 360 - \theta & \text{if } B > G
# \end{cases}
# $$
#
# Với góc $\theta$ được tính
#
# $$
# \theta = \cos^{-1} \left\{
# \frac{
# \frac{1}{2} \left[ (R - G) + (R - B) \right]
# }{
# \left[ (R - G)^2 + (R - B)(G - B) \right]^{1/2}
# }
# \right\}
# $$
#
# Đại lượng S được tính dựa trên
#
# $$
# S = 1 - \frac{3}{R + G + B} \left[ \min(R, G, B) \right]
# $$
#
# Cuối cùng Value được tính dựa trên
#
# $$
# V = \frac{1}{3}(R + G + B)
# $$
#
# - Chuyển từ không gian HSV sang không gian RGB
#
# Giả sử các đại lượng đã được chuẩn hóa trong đoạn $[0,1]$, với $H \in [0,360^\circ]$.
#
# Ta chia theo 3 miền giá trị của Hue:
#
# **1) Sector RG ($0^\circ \leq H < 120^\circ$)**
# $$
# B = V(1-S)
# $$
# $$
# R = V\left[1 + \frac{S\cos H}{\cos(60^\circ - H)}\right]
# $$
# $$
# G = 3V - (R + B)
# $$
#
# **2) Sector GB ($120^\circ \leq H < 240^\circ$)**
# Đặt $H' = H - 120^\circ$, khi đó:
# $$
# R = V(1-S)
# $$
# $$
# G = V\left[1 + \frac{S\cos H'}{\cos(60^\circ - H')}\right]
# $$
# $$
# B = 3V - (R + G)
# $$
#
# **3) Sector BR ($240^\circ \leq H \leq 360^\circ$)**
# Đặt $H'' = H - 240^\circ$, khi đó:
# $$
# G = V(1-S)
# $$
# $$
# B = V\left[1 + \frac{S\cos H''}{\cos(60^\circ - H'')}\right]
# $$
# $$
# R = 3V - (G + B)
# $$
#
# Sau khi tính xong, nếu cần về thang 8-bit thì nhân mỗi kênh với 255 và ép về đoạn $[0,255]$.
#
# <a id="sec-2-3"></a>
#
# ## 2.3. Không gian RGB sang không gian LAB
#
#
# #### Bước 1: Chuẩn hóa RGB và khử gamma (sRGB)
#
# Cho giá trị RGB ban đầu trong khoảng $[0,255]$:
#
# $$
# R' = \frac{R}{255}, \quad G' = \frac{G}{255}, \quad B' = \frac{B}{255}
# $$
#
# Khử gamma:
#
# $$
# C_{lin} =
# \begin{cases}
# \frac{C'}{12.92} & \text{nếu } C' \le 0.04045 \\
# \left(\frac{C' + 0.055}{1.055}\right)^{2.4} & \text{nếu } C' > 0.04045
# \end{cases}
# $$
#
# Áp dụng cho $R', G', B'$ để thu được:
#
# $$
# R_{lin}, \quad G_{lin}, \quad B_{lin}
# $$
#
#
# #### Bước 2: Chuyển từ Linear RGB → XYZ
#
# Sử dụng ma trận chuyển đổi (chuẩn sRGB, illuminant D65):
#
# $$
# \begin{bmatrix}
# X \\
# Y \\
# Z
# \end{bmatrix}
# =
# \begin{bmatrix}
# 0.4124 & 0.3576 & 0.1805 \\
# 0.2126 & 0.7152 & 0.0722 \\
# 0.0193 & 0.1192 & 0.9505
# \end{bmatrix}
# \begin{bmatrix}
# R_{lin} \\
# G_{lin} \\
# B_{lin}
# \end{bmatrix}
# $$
#
#
# #### Bước 3: Chuẩn hóa XYZ theo điểm trắng D65
#
# $$
# X_n = 95.047, \quad Y_n = 100.000, \quad Z_n = 108.883
# $$
#
# $$
# x = \frac{X}{X_n}, \quad y = \frac{Y}{Y_n}, \quad z = \frac{Z}{Z_n}
# $$
#
#
# #### Bước 4: Áp dụng hàm phi tuyến
#
# $$
# f(t) =
# \begin{cases}
# t^{1/3} & \text{nếu } t > 0.008856 \\
# 7.787t + \frac{16}{116} & \text{ngược lại}
# \end{cases}
# $$
#
#
# #### Bước 5: Tính giá trị LAB
#
# $$
# L^* = 116 f(y) - 16
# $$
#
# $$
# a^* = 500 \big(f(x) - f(y)\big)
# $$
#
# $$
# b^* = 200 \big(f(y) - f(z)\big)
# $$
#
# <a id="sec-2-4"></a>
#
# ## 2.4 Tổng kết quá trình tính toán
# $$
# RGB \rightarrow RGB_{linear} \rightarrow XYZ \rightarrow LAB
# $$

# %% [markdown]
# <a id="sec-3"></a>
#
# # 3. Không gian màu trong bài toán Classification và phương sai giải thích
# Trong thực tế, khi xử lý ảnh, chúng ta phải đối mặt với rất nhiều vấn đề liên quan đến tài nguyên xử lý như tập dữ liệu rất lớn (hàng ngàn, hàng vạn bức ảnh), mỗi bức ảnh thường có quality từ trung bình trở lên dẫn đến việc xử lý đơn lẻ một bức ảnh cũng có thể kiến cho máy tính xử lý phức tạp hơn. Vì thế họ mới cố gắng tìm mọi cách để đưa dữ liệu về dạng dễ sử dụng hơn, chỉ tập trung vào đặc trưng, dễ cho máy tính có thể tính toán. Một trong những cách đó chính là chuyển đổi giữa các không gian màu. Tưởng tượng một ảnh RGB có thể có tới ~16,8 triệu cách biểu diễn màu trên một pixel, nhưng nếu đưa qua không gian HSV thì chỉ cần hơn ~300.000 giá trị để có thể biểu diễn 16,8 triệu màu RGB. Nhưng nói đi cũng phải nói lại, đánh đổi việc tiết kiệm chính là đối mặt với sự mất mát thông tin. Đối với người bình thường, chỉ cần chuyển một chiếc lá từ RGB sang HSV thì có thể con người đã không thể nhận ra đó là chiếc lá. Vì vậy khi chọn không gian màu phù hợp, người ta đã đưa ra khái niệm **Phương sai giải thích** để đo đạc mức độ mất mát thông tin.
#
# #### Phương sai giải thích
# - Phương sai giải thích (Explained Variance) là một khái niệm trong thống kê và học máy, dùng đo mức độ mà mô hình hoặc một biến có thể giải thích được sự biến thiên của dữ liệu.
# - Giá trị dữ liệu luôn có sự giao động mà người ta tính toán được gọi là phương sai, mô hình có thể giải thích được một phần được gọi là phương sai giải thích
# - VD: Người ta mong muốn khảo sát được thời gian trung bình di chuyển từ nhà đến trường học, mô hình xây dựng dựa vào "Số đèn đỏ" mà bạn gặp để dự đoán, giải thích và cho rằng số đèn đỏ là một trong yếu tố ảnh hưởng đến thời gian đi học. Phần mà mô hình giải thích được, được gọi là phương sai giải thích.
# - Liên hệ đến việc chuyển đổi giữa các không gian màu, ta sẽ dùng PCA để tìm các trục trong không gian. PCA sẽ chọn các trục có phương sai lớn nhất để giữ lại, từ đó lượng thông tin được giữ chính là phương sai được chiếu theo trục đó. Từ đó ta có công thức tính phương sai giải thích của thành phần thứ k:
#
# ### Tổng phương sai
#
# $$
# \mathrm{Var}_{total} = \sum_{i=1}^{d} \lambda_i
# $$
#
# Trong đó:
# - $\lambda_i$ là eigenvalue thứ $i$
# - $d$ là số chiều ban đầu của dữ liệu
#
# ### Phương sai giải thích của thành phần thứ k
#
# $$
# \mathrm{Explained\ Variance\ Ratio}_k = \frac{\lambda_k}{\sum_{i=1}^{d} \lambda_i}
# $$
#
# ### Tổng phương sai giải thích với k thành phần
#
# $$
# \mathrm{Total\ Explained\ Variance} = \sum_{k=1}^{K} \frac{\lambda_k}{\sum_{i=1}^{d} \lambda_i}
# $$
#
# ### Dạng vector (thường dùng trong PCA)
#
# Giả sử vector eigenvalues:
#
# $$
# \Lambda = [\lambda_1, \lambda_2, ..., \lambda_d]
# $$
#
# Thì:
#
# $$
# \mathrm{Explained\ Variance\ Ratio} = \frac{\Lambda}{\sum_{i=1}^{d} \lambda_i}
# $$

# %%
# Import thư viện, nạp dataset vào
import sys, os, warnings
import logging

warnings.filterwarnings("ignore")
os.environ["OPENCV_LOG_LEVEL"] = "SILENT"
logging.getLogger("cv2").setLevel(logging.ERROR)

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

if os.path.abspath('../src') not in sys.path:
    sys.path.append(os.path.abspath('../src'))

from image.dataset import ImageDataset
from image.preprocessing_color_transform import ColorTransformEvaluator
from config.settings import PATH_FOLDER_IMAGE_RAW, SUPPORT_COLOR_SPACE
from visualization.evaluation import plot_color_space_evaluation
from IPython.display import display

print("[INFO] Đang nạp Dataset gốc...")
dataset = ImageDataset(path=PATH_FOLDER_IMAGE_RAW)
dataset.info()
# Out:
# [INFO] Đang nạp Dataset gốc...
# Metadata of Dataset
# 	Folder Path: /home/duyhoang/Downloads/Data mining/Project/data-mining-preprocessing-project/data/image
# 	Total Images: 0
# 	Image Size:(128, 128)
# 	Dataset Shape:(0, 0, 0, 0) (N,H,W,C)
# 	Name of file of 5 first sample

# %%
results = []

for space in SUPPORT_COLOR_SPACE:
    print(f"\n{'='*50}\n ĐANG XỬ LÝ: {space}\n{'='*50}")
    
    # Dùng Class Evaluator thay vì class gốc
    transformer = ColorTransformEvaluator(method=space, n=50)
    transformer.run(dataset)
    
    # Đánh giá (n_repeats=3)
    metrics = transformer.evaluation(dataset, n_repeats=3)
    
    # Gọi hàm lưu ảnh
    transformer.save_images(dataset)
    
    # Ghi nhận kết quả
    results.append({
        "Color_Space": space,
        "Variance_Ratio_Sum": transformer._explanied_variance_ratio_sum,
        "Accuracy": metrics["accuracy"],
        "Precision": metrics["precision"],
        "Recall": metrics["recall"],
        "F1_Score": metrics["f1_score"]
    })

# Vẽ biểu đồ tổng kết
import visualization.evaluation as eval_viz
eval_viz.plt.show = lambda: display(eval_viz.plt.gcf())

print("\n[INFO] ĐANG VẼ BIỂU ĐỒ TỐNG KẾT...")
plot_color_space_evaluation(results)
# Out:
# ...
#  ĐANG XỬ LÝ: HSV
# ...
#    [INFO] Đang chạy Tiền xử lý (Fast-Cache Mode)...
# Bước xử lý : Preprocessing: Color Space Transform
# Tập dữ liệu: Image Dataset
# Trạng thái : Success
# Không gian màu: HSV
# Tổng phương sai giải thích theo PCA với k=50: 31096.395557278236
# Tổng tỷ lệ phương sai giải thích:0.6326336206027873
# PC1: 0.165148
# PC2: 0.107013
# PC3: 0.071380
# PC4: 0.034975
# PC5: 0.023841
#
# [EVALUATION] Bắt đầu huấn luyện mô hình (Không gian: HSV)...
# [RESULT] HSV (Mất 27.6s) - F1: 0.3069
#
#    [INFO] Đang xuất file ảnh ra: ../data/preprocessing/color_space/hsv ... (Vui lòng đợi)
#    [SUCCESS] Đã lưu xong ảnh cho không gian màu HSV!
#
# ...
#  ĐANG XỬ LÝ: RGB
# ...
#    [INFO] Đang chạy Tiền xử lý (Fast-Cache Mode)...
# Bước xử lý : Preprocessing: Color Space Transform
# Tập dữ liệu: Image Dataset
# Trạng thái : Success
# Không gian màu: RGB
# Tổng phương sai giải thích theo PCA với k=50: 35727.60238120046
# Tổng tỷ lệ phương sai giải thích:0.726852165494319
# PC1: 0.297457
# ...

# %% [markdown]
# <a id="sec-4"></a>
#
# # 4. Tổng kết thực nghiệm: Phân tích và đánh giá tiền xử lý không gian màu
#
# Dựa trên kết quả thực nghiệm với mô hình Logistic Regression và thuật toán giảm chiều dữ liệu PCA (k=50) trên bộ dữ liệu gốc, ta có những phân tích chuyên sâu như sau:
#
# <a id="sec-4-1"></a>
#
# ## 4. 1. Đánh giá dựa trên Phương sai giải thích (Khả năng giữ thông tin)
# Dựa vào biểu đồ "Tỷ lệ Phương sai giải thích", các không gian màu xếp hạng theo khả năng giữ thông tin khi nén xuống 50 chiều như sau: **Grayscale (0.7428) > RGB (0.7270) > LAB (0.7253) > HSV (0.6324)**.
#
# * **Không gian tốt nhất (về mặt số liệu):** Grayscale. Do đã gộp 3 kênh màu thành 1 kênh cường độ sáng, dữ liệu trở nên đơn giản hơn rất nhiều. Việc dùng 50 thành phần chính (PCs) dễ dàng thâu tóm được phần lớn sự biến thiên (phương sai) của bức ảnh.
# * **Không gian tệ nhất:** HSV (chỉ giữ được 63.24%).
# * **Vị trí của các không gian ở giữa:** RGB (0.7270) và LAB (0.7253) nằm ở mức giữa, nhưng chúng có giá trị **gần sát với không gian đứng nhất (Grayscale)** và bỏ khá xa không gian đứng bét (HSV).
#
# <a id="sec-4-2"></a>
#
# ## 4.2. Số lượng màu biểu diễn có quyết định khả năng giữ thông tin?
# Theo lý thuyết, RGB có thể biểu diễn khoảng ~16.8 triệu màu, trong khi đó HSV biểu diễn số lượng màu ít hơn do hệ thống tọa độ hình trụ nén các giá trị lại. Tuy nhiên, **khả năng giữ thông tin (phương sai giải thích) không phụ thuộc vào số lượng màu mà không gian đó biểu diễn.** * **Vì sao Phương sai HSV (0.6324) lại nhỏ hơn RGB (0.7270)?** Trong không gian RGB, 3 kênh màu (Đỏ, Lục, Lam) có độ tương quan rất chặt chẽ với **cường độ ánh sáng**. Khi một bức ảnh bị hắt nắng hoặc nằm trong bóng râm, cả 3 giá trị R, G, B đều đồng loạt tăng hoặc giảm. Sự dao động ánh sáng này tạo ra một lượng "phương sai rác" khổng lồ mà thuật toán PCA lầm tưởng là thông tin quan trọng.
#   Ngược lại, không gian HSV đã cô lập hoàn toàn ánh sáng vào kênh V (Value), để lại kênh H (Hue - Sắc độ) và S (Saturation - Độ bão hòa) mang đặc trưng màu thuần túy. Sự tách bạch này làm giảm đi sự biến thiên vô ích do ánh sáng gây ra, dẫn đến tổng phương sai của HSV thấp hơn.
# * **Thực tế ứng dụng:** Mặc dù PCA giữ được ít phương sai hơn, nhưng trong thực tế các kỹ sư thị giác máy tính **thích sử dụng HSV (hoặc LAB) hơn RGB**. Lý do là vì HSV giữ lại "phương sai có ích" (màu sắc thực), loại bỏ được nhiễu do điều kiện chiếu sáng.
#
# <a id="sec-4-3"></a>
#
# ## 4.3. Phân tích Độ đo Chính xác (F1-Score) cho bài toán Phân loại Động vật
# Dựa vào biểu đồ F1-Score, kết quả nghịch đảo hoàn toàn với phương sai: **HSV (0.3084) > LAB (0.3040) > RGB (0.2579) > Grayscale (0.2254)**.
#
# * **Giải thích nguyên nhân TĂNG chỉ số (Đối với HSV, LAB):** Tại sao phương sai thấp mà F1 lại cao nhất? Bài toán phân loại động vật hoang dã phụ thuộc cực lớn vào **họa tiết và màu sắc đặc trưng** (ví dụ: vằn cam của hổ, lông trắng/đen của gấu trúc). Ảnh chụp ngoài tự nhiên luôn bị nhiễu bóng râm và chói nắng. Do HSV và LAB tách rời kênh ánh sáng (V và L), mô hình Logistic Regression không bị bối rối bởi các mảng tối/sáng, chỉ tập trung học thuộc màu sắc (H, S, a, b). Việc làm sạch đặc trưng này giúp F1-score của HSV tăng vọt lên ~5% tuyệt đối (tương đương cải thiện ~19% hiệu suất so với RGB).
# * **Giải thích nguyên nhân giảm chỉ số (Đối với Grayscale, RGB):** * *Grayscale giảm mạnh nhất:* Vì nó đã vứt bỏ hoàn toàn thông tin màu sắc (chỉ còn sắc xám). Mô hình không thể phân biệt được một con cáo vàng và một con sói xám nếu chúng có cùng độ sáng. Việc mất thông tin gốc làm độ đo giảm thê thảm.
#     * *RGB thấp hơn HSV:* Do tính chất tuyến tính của Logistic Regression, nó không có khả năng tự giải mã và bóc tách nhiễu ánh sáng đang hòa quyện trong cả 3 kênh R-G-B, khiến việc hội tụ các trọng số phân loại trở nên kém hiệu quả.
#
# <a id="sec-4-4"></a>
#
# ## 4.4. Bàn luận: Sự đánh đổi giữa Độ phức tạp và Khả năng giữ thông tin
# Quá trình chuyển đổi từ RGB (gốc) sang các không gian khác tiêu tốn độ phức tạp tính toán khác nhau:
# * **Grayscale:** Phép tính ma trận đơn giản (nhân trọng số cộng dồn), cực kỳ nhanh (Time Complexity O(N)).
# * **HSV / LAB:** Yêu cầu các phép biến đổi toán học phi tuyến phức tạp (tìm Max/Min, phép chia, hàm lượng giác cho góc Hue, căn bậc 3 cho LAB). Việc này gây tốn thời gian CPU đáng kể cho khâu Tiền xử lý.
#
# **Đánh đổi có xứng đáng không?** Đối với bài toán phân loại này, **sự đánh đổi là hoàn toàn xứng đáng**. Thay vì tốn kém tài nguyên xây dựng một Mạng Nơ-ron sâu thẳm (Deep Learning) để tự học cách chống nhiễu ánh sáng, ta chỉ cần tốn thêm một chút thời gian (O(N) operations) ở khâu Tiền xử lý để chuyển sang HSV hoặc LAB. Thuật toán phân loại học máy đơn giản (Logistic Regression) sau đó sẽ được làm việc trên một không gian đặc trưng sạch, học nhanh hơn và dự đoán chính xác hơn rất nhiều.
